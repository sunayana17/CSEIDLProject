# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from os.path import join
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
class_enc = LabelEncoder()
import pickle
import tensorflow as tf
import cv2
import keras.backend as K
# Out:
# /packages/7x/anaconda3/5.3.0/envs/tf2.4.1-gpu/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# 2022-12-02 14:01:47.713393: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-02 14:01:47.845479: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-02 14:01:47.881754: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-02 14:01:50.225343: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /packages/7x/anaconda3/5.3.0/lib
# 2022-12-02 14:01:50.225512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /packages/7x/anaconda3/5.3.0/lib
# 2022-12-02 14:01:50.225535: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# %pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already up-to-date: scikit-learn in /home/sgupt279/.local/lib/python3.8/site-packages (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3 in /home/sgupt279/.local/lib/python3.8/site-packages (from scikit-learn) (1.23.3)
# Requirement already satisfied, skipping upgrade: joblib>=1.0.0 in /home/sgupt279/.local/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/sgupt279/.local/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.2 in /packages/7x/anaconda3/5.3.0/envs/tf2.4.1-gpu/lib/python3.8/site-packages (from scikit-learn) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# params we will probably want to do some hyperparameter optimization later
BASE_MODEL= 'InceptionV3' # ['VGG16', 'RESNET52', 'InceptionV3', 'Xception', 'DenseNet169', 'DenseNet121']
IMG_SIZE = (384, 384) # [(224, 224), (384, 384), (512, 512), (640, 640)]
BATCH_SIZE = 24 # [1, 8, 16, 24]
DENSE_COUNT = 128 # [32, 64, 128, 256]
DROPOUT = 0.25 # [0, 0.25, 0.5]
LEARN_RATE = 1e-4 # [1e-4, 1e-3, 4e-3]
TRAIN_SAMPLES = 8000 # [3000, 6000, 15000]
TEST_SAMPLES = 800
USE_ATTN = False # [True, False]

# %%
from keras.preprocessing.image import ImageDataGenerator
if BASE_MODEL=='VGG16':
    from keras.applications.vgg16 import VGG16 as PTModel, preprocess_input
elif BASE_MODEL=='RESNET52':
    from keras.applications.resnet import ResNet50 as PTModel, preprocess_input
elif BASE_MODEL=='InceptionV3':
    from keras.applications.inception_v3 import InceptionV3 as PTModel, preprocess_input
elif BASE_MODEL=='DenseNet169': 
    from keras.applications.densenet import DenseNet169 as PTModel, preprocess_input
elif BASE_MODEL=='NASNetLarge':
    from keras.applications.nasnet import NASNetLarge as PTModel, preprocess_input
else:
    raise ValueError('Unknown model: {}'.format(BASE_MODEL))

# %%
img_gen_args = dict(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range = 0.05, 
                              width_shift_range = 0.02, 
                              rotation_range = 3, 
                              shear_range = 0.01,
                              fill_mode = 'nearest',
                              zoom_range = 0.05,
                               preprocessing_function=preprocess_input)
img_gen = ImageDataGenerator(**img_gen_args)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_HUMERUS.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_HUMERUS.csv", dtype=str)
train_df
# Out:
#                                             Train_Image Train_Label
# 0     MURA-v1.1/train/XR_HUMERUS/patient02695/study1...           1
# 1     MURA-v1.1/train/XR_HUMERUS/patient02626/study1...           1
# 2     MURA-v1.1/train/XR_HUMERUS/patient02626/study1...           1
# 3     MURA-v1.1/train/XR_HUMERUS/patient02696/study1...           1
# 4     MURA-v1.1/train/XR_HUMERUS/patient02696/study1...           1
# ...                                                 ...         ...
# 1267  MURA-v1.1/train/XR_HUMERUS/patient03224/study1...           0
# 1268  MURA-v1.1/train/XR_HUMERUS/patient03225/study1...           0
# 1269  MURA-v1.1/train/XR_HUMERUS/patient03225/study1...           0
# 1270  MURA-v1.1/train/XR_HUMERUS/patient03226/study1...           0
# 1271  MURA-v1.1/train/XR_HUMERUS/patient03226/study1...           0
#
# [1272 rows x 2 columns]

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_ELBOW.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_ELBOW.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_SHOULDER.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_SHOULDER.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_HAND.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_HAND.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_FINGER.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_FINGER.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_FOREARM.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_FOREARM.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_WRIST.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_WRIST.csv", dtype=str)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Image Preprocessing
train_generator = train_datagen.flow_from_dataframe(dataframe=train_df, directory=None,
                                              x_col="Train_Image", y_col="Train_Label",
                                              target_size=(224,224), class_mode="categorical",
                                              batch_size=BATCH_SIZE, shuffle=True)

validation_generator = validation_datagen.flow_from_dataframe(dataframe=valid_df, directory=None,
                                              x_col="Valid_Image", y_col="Valid_Label",
                                              target_size=(224,224), class_mode="categorical",
                                              batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Found 9752 validated image filenames belonging to 2 classes.
# Found 659 validated image filenames belonging to 2 classes.

# %%
t_x, t_y = next(train_generator)
print(t_x.shape, t_y.shape)
fig, m_axs = plt.subplots(2, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    #c_ax.set_title('%s' % class_enc.classes_[np.argmax(c_y)])
    c_ax.axis('off')
# Out:
# (24, 224, 224, 3) (24, 2)

# %%
base_pretrained_model = PTModel(input_shape =  t_x.shape[1:], 
                              include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False
# Out:
# 2022-12-02 14:02:00.853031: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sgupt279/.local/lib/python3.8/site-packages/cv2/../../lib64:/packages/7x/anaconda3/5.3.0/lib
# 2022-12-02 14:02:00.853085: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-02 14:02:00.854025: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
t_x.shape[1:]
# Out:
# (224, 224, 3)

# %%
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, Input, Conv2D, multiply, LocallyConnected2D, Lambda, AvgPool2D
from keras.models import Model
from keras.optimizers import Adam
from keras import layers
in_lay = Input(t_x.shape[1:])
pt_features = base_pretrained_model(in_lay)
#pt_features = Input(base_pretrained_model.get_output_shape_at(0)[1:], name = 'feature_input')
pt_depth = base_pretrained_model.get_output_shape_at(0)[-1]
from keras.layers import BatchNormalization
bn_features = BatchNormalization()(pt_features)
gap = GlobalAveragePooling2D()(bn_features)

gap_dr = Dropout(DROPOUT)(gap)
dr_steps = Dropout(DROPOUT)(Dense(DENSE_COUNT, activation = 'linear', use_bias=False)(gap_dr))
dr_steps = BatchNormalization()(dr_steps)
dr_steps = layers.LeakyReLU(0.1)(dr_steps)
out_layer = Dense(t_y.shape[1], activation = 'softmax')(dr_steps)

attn_model = Model(inputs = [pt_features], 
                   outputs = [out_layer], name = 'trained_model')

attn_model.summary()
# Out:
# Model: "trained_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 5, 5, 2048)]      0
#
#  batch_normalization_94 (Bat  (None, 5, 5, 2048)       8192
#  chNormalization)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262144
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  batch_normalization_95 (Bat  (None, 128)              512
#  chNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 271,106
# Trainable params: 266,754
# Non-trainable params: 4,352
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.optimizers import Adam
pneu_model = Sequential(name = 'combined_model')
base_pretrained_model.trainable = False
pneu_model.add(base_pretrained_model)
pneu_model.add(attn_model)
pneu_model.compile(optimizer = Adam(lr = LEARN_RATE), loss = 'categorical_crossentropy',
                           metrics = ['categorical_accuracy'])
pneu_model.summary()
# Out:
# Model: "combined_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  trained_model (Functional)  (None, 2)                 271106
#
# =================================================================
# Total params: 22,073,890
# Trainable params: 266,754
# Non-trainable params: 21,807,136
# _________________________________________________________________
# /home/sgupt279/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('lung_opacity1')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, 
                                   patience=10, verbose=1, mode='auto', 
                                   epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=10) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
train_generator.batch_size = BATCH_SIZE
history=pneu_model.fit_generator(train_generator, 
                         steps_per_epoch=train_generator.n//BATCH_SIZE,
                         validation_data=validation_generator, 
                         validation_steps=validation_generator.n//BATCH_SIZE,
                         epochs=30, 
                         callbacks=callbacks_list,
                         workers=2)
# Out:
# /tmp/ipykernel_168371/3775246973.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=pneu_model.fit_generator(train_generator,
# Epoch 1/30
# 406/406 [==============================] - ETA: 0s - loss: 0.6482 - categorical_accuracy: 0.6622
# Epoch 1: val_loss improved from inf to 0.54523, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 204s 492ms/step - loss: 0.6482 - categorical_accuracy: 0.6622 - val_loss: 0.5452 - val_categorical_accuracy: 0.7222 - lr: 1.0000e-04
# Epoch 2/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5772 - categorical_accuracy: 0.7121
# Epoch 2: val_loss improved from 0.54523 to 0.51631, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 200s 490ms/step - loss: 0.5772 - categorical_accuracy: 0.7121 - val_loss: 0.5163 - val_categorical_accuracy: 0.7469 - lr: 1.0000e-04
# Epoch 3/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5677 - categorical_accuracy: 0.7184
# Epoch 3: val_loss improved from 0.51631 to 0.50572, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 201s 493ms/step - loss: 0.5677 - categorical_accuracy: 0.7184 - val_loss: 0.5057 - val_categorical_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 4/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5498 - categorical_accuracy: 0.7282
# Epoch 4: val_loss improved from 0.50572 to 0.49448, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 199s 487ms/step - loss: 0.5498 - categorical_accuracy: 0.7282 - val_loss: 0.4945 - val_categorical_accuracy: 0.7531 - lr: 1.0000e-04
# Epoch 5/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5430 - categorical_accuracy: 0.7275
# Epoch 5: val_loss did not improve from 0.49448
# 406/406 [==============================] - 192s 472ms/step - loss: 0.5430 - categorical_accuracy: 0.7275 - val_loss: 0.4961 - val_categorical_accuracy: 0.7670 - lr: 1.0000e-04
# Epoch 6/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5364 - categorical_accuracy: 0.7355
# Epoch 6: val_loss improved from 0.49448 to 0.49160, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 200s 491ms/step - loss: 0.5364 - categorical_accuracy: 0.7355 - val_loss: 0.4916 - val_categorical_accuracy: 0.7562 - lr: 1.0000e-04
# Epoch 7/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5284 - categorical_accuracy: 0.7407
# Epoch 7: val_loss improved from 0.49160 to 0.48157, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 199s 487ms/step - loss: 0.5284 - categorical_accuracy: 0.7407 - val_loss: 0.4816 - val_categorical_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 8/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5245 - categorical_accuracy: 0.7437
# Epoch 8: val_loss improved from 0.48157 to 0.47214, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 205s 502ms/step - loss: 0.5245 - categorical_accuracy: 0.7437 - val_loss: 0.4721 - val_categorical_accuracy: 0.7670 - lr: 1.0000e-04
# Epoch 9/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5213 - categorical_accuracy: 0.7409
# Epoch 9: val_loss did not improve from 0.47214
# 406/406 [==============================] - 181s 443ms/step - loss: 0.5213 - categorical_accuracy: 0.7409 - val_loss: 0.4859 - val_categorical_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 10/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5150 - categorical_accuracy: 0.7497
# Epoch 10: val_loss did not improve from 0.47214
# 406/406 [==============================] - 200s 490ms/step - loss: 0.5150 - categorical_accuracy: 0.7497 - val_loss: 0.4913 - val_categorical_accuracy: 0.7577 - lr: 1.0000e-04
# Epoch 11/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5187 - categorical_accuracy: 0.7427
# Epoch 11: val_loss did not improve from 0.47214
# 406/406 [==============================] - 199s 489ms/step - loss: 0.5187 - categorical_accuracy: 0.7427 - val_loss: 0.4769 - val_categorical_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 12/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4996 - categorical_accuracy: 0.7557
# Epoch 12: val_loss did not improve from 0.47214
# 406/406 [==============================] - 194s 475ms/step - loss: 0.4996 - categorical_accuracy: 0.7557 - val_loss: 0.4840 - val_categorical_accuracy: 0.7577 - lr: 1.0000e-04
# Epoch 13/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5044 - categorical_accuracy: 0.7542
# Epoch 13: val_loss did not improve from 0.47214
# 406/406 [==============================] - 203s 497ms/step - loss: 0.5044 - categorical_accuracy: 0.7542 - val_loss: 0.4790 - val_categorical_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 14/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5052 - categorical_accuracy: 0.7510
# Epoch 14: val_loss did not improve from 0.47214
# 406/406 [==============================] - 200s 491ms/step - loss: 0.5052 - categorical_accuracy: 0.7510 - val_loss: 0.4761 - val_categorical_accuracy: 0.7701 - lr: 1.0000e-04
# Epoch 15/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5042 - categorical_accuracy: 0.7553
# Epoch 15: val_loss improved from 0.47214 to 0.47027, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 199s 488ms/step - loss: 0.5042 - categorical_accuracy: 0.7553 - val_loss: 0.4703 - val_categorical_accuracy: 0.7701 - lr: 1.0000e-04
# Epoch 16/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5034 - categorical_accuracy: 0.7535
# Epoch 16: val_loss did not improve from 0.47027
# 406/406 [==============================] - 200s 490ms/step - loss: 0.5034 - categorical_accuracy: 0.7535 - val_loss: 0.4714 - val_categorical_accuracy: 0.7824 - lr: 1.0000e-04
# Epoch 17/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4973 - categorical_accuracy: 0.7607
# Epoch 17: val_loss did not improve from 0.47027
# 406/406 [==============================] - 198s 487ms/step - loss: 0.4973 - categorical_accuracy: 0.7607 - val_loss: 0.4748 - val_categorical_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 18/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4993 - categorical_accuracy: 0.7578
# Epoch 18: val_loss did not improve from 0.47027
# 406/406 [==============================] - 199s 489ms/step - loss: 0.4993 - categorical_accuracy: 0.7578 - val_loss: 0.4777 - val_categorical_accuracy: 0.7809 - lr: 1.0000e-04
# Epoch 19/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4970 - categorical_accuracy: 0.7583
# Epoch 19: val_loss did not improve from 0.47027
# 406/406 [==============================] - 194s 475ms/step - loss: 0.4970 - categorical_accuracy: 0.7583 - val_loss: 0.4712 - val_categorical_accuracy: 0.7840 - lr: 1.0000e-04
# Epoch 20/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4934 - categorical_accuracy: 0.7635
# Epoch 20: val_loss did not improve from 0.47027
# 406/406 [==============================] - 208s 510ms/step - loss: 0.4934 - categorical_accuracy: 0.7635 - val_loss: 0.4703 - val_categorical_accuracy: 0.7762 - lr: 1.0000e-04
# Epoch 21/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4990 - categorical_accuracy: 0.7598
# Epoch 21: val_loss improved from 0.47027 to 0.46684, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 191s 468ms/step - loss: 0.4990 - categorical_accuracy: 0.7598 - val_loss: 0.4668 - val_categorical_accuracy: 0.7901 - lr: 1.0000e-04
# Epoch 22/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4920 - categorical_accuracy: 0.7632
# Epoch 22: val_loss did not improve from 0.46684
# 406/406 [==============================] - 199s 490ms/step - loss: 0.4920 - categorical_accuracy: 0.7632 - val_loss: 0.4758 - val_categorical_accuracy: 0.7716 - lr: 1.0000e-04
# Epoch 23/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4981 - categorical_accuracy: 0.7619
# Epoch 23: val_loss did not improve from 0.46684
# 406/406 [==============================] - 200s 490ms/step - loss: 0.4981 - categorical_accuracy: 0.7619 - val_loss: 0.4914 - val_categorical_accuracy: 0.7577 - lr: 1.0000e-04
# Epoch 24/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4941 - categorical_accuracy: 0.7594
# Epoch 24: val_loss did not improve from 0.46684
# 406/406 [==============================] - 196s 482ms/step - loss: 0.4941 - categorical_accuracy: 0.7594 - val_loss: 0.4766 - val_categorical_accuracy: 0.7747 - lr: 1.0000e-04
# Epoch 25/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4865 - categorical_accuracy: 0.7703
# Epoch 25: val_loss did not improve from 0.46684
# 406/406 [==============================] - 200s 492ms/step - loss: 0.4865 - categorical_accuracy: 0.7703 - val_loss: 0.4805 - val_categorical_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 26/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4916 - categorical_accuracy: 0.7619
# Epoch 26: val_loss did not improve from 0.46684
# 406/406 [==============================] - 201s 493ms/step - loss: 0.4916 - categorical_accuracy: 0.7619 - val_loss: 0.4813 - val_categorical_accuracy: 0.7654 - lr: 1.0000e-04
# Epoch 27/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4896 - categorical_accuracy: 0.7663
# Epoch 27: val_loss did not improve from 0.46684
# 406/406 [==============================] - 203s 499ms/step - loss: 0.4896 - categorical_accuracy: 0.7663 - val_loss: 0.4844 - val_categorical_accuracy: 0.7716 - lr: 1.0000e-04
# Epoch 28/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4880 - categorical_accuracy: 0.7681
# Epoch 28: val_loss did not improve from 0.46684
# 406/406 [==============================] - 201s 495ms/step - loss: 0.4880 - categorical_accuracy: 0.7681 - val_loss: 0.4832 - val_categorical_accuracy: 0.7716 - lr: 1.0000e-04
# Epoch 29/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4886 - categorical_accuracy: 0.7674
# Epoch 29: val_loss did not improve from 0.46684
# 406/406 [==============================] - 197s 484ms/step - loss: 0.4886 - categorical_accuracy: 0.7674 - val_loss: 0.4829 - val_categorical_accuracy: 0.7716 - lr: 1.0000e-04
# Epoch 30/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4809 - categorical_accuracy: 0.7731
# Epoch 30: val_loss did not improve from 0.46684
# 406/406 [==============================] - 201s 494ms/step - loss: 0.4809 - categorical_accuracy: 0.7731 - val_loss: 0.4812 - val_categorical_accuracy: 0.7716 - lr: 1.0000e-04

# %%
with open('elbow_vgg16_model.pkl', 'wb') as pickle_out:  
    pickle.dump(history, pickle_out)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 94). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://71747afe-9fc4-4e80-8411-cb76a5e45cf7/assets
# INFO:tensorflow:Assets written to: ram://71747afe-9fc4-4e80-8411-cb76a5e45cf7/assets

# %%
# %pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /home/sgupt279/.local/lib/python3.8/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm


valid_flow = validation_datagen.flow_from_dataframe(dataframe=valid_df, directory=None,
                                              x_col="Valid_Image", y_col="Valid_Label",
                                              target_size=(224,224), class_mode="categorical",
                                              batch_size=BATCH_SIZE, shuffle=False)


out_x, out_y, pred_y = [], [], []
for _, (tX, tY) in zip(tqdm(range(len(valid_flow.filenames)//32)), valid_flow):
    out_x += [tX]
    out_y += [tY]
    pred_y += [pneu_model.predict(tX)]
# Out:
# Found 659 validated image filenames belonging to 2 classes.
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 [==============================] - 2s 2s/step
#   5%|▌         | 1/20 [00:02<00:54,  2.89s/it]
# 1/1 [==============================] - 0s 350ms/step
#  10%|█         | 2/20 [00:03<00:27,  1.54s/it]
# 1/1 [==============================] - 0s 396ms/step
#  15%|█▌        | 3/20 [00:04<00:19,  1.15s/it]
# 1/1 [==============================] - 0s 397ms/step
#  20%|██        | 4/20 [00:04<00:15,  1.03it/s]
# 1/1 [==============================] - 0s 398ms/step
#  25%|██▌       | 5/20 [00:05<00:14,  1.07it/s]
# 1/1 [==============================] - 0s 441ms/step
#  30%|███       | 6/20 [00:06<00:12,  1.08it/s]
# 1/1 [==============================] - 0s 362ms/step
#  35%|███▌      | 7/20 [00:07<00:11,  1.12it/s]
# 1/1 [==============================] - 0s 416ms/step
#  40%|████      | 8/20 [00:08<00:10,  1.16it/s]
# 1/1 [==============================] - 0s 421ms/step
#  45%|████▌     | 9/20 [00:08<00:09,  1.22it/s]
# 1/1 [==============================] - 0s 405ms/step
#  50%|█████     | 10/20 [00:09<00:07,  1.26it/s]
# 1/1 [==============================] - 0s 379ms/step
#  55%|█████▌    | 11/20 [00:10<00:07,  1.16it/s]
# 1/1 [==============================] - 0s 382ms/step
#  60%|██████    | 12/20 [00:11<00:06,  1.24it/s]
# 1/1 [==============================] - 0s 409ms/step
#  65%|██████▌   | 13/20 [00:12<00:05,  1.25it/s]
# 1/1 [==============================] - 0s 398ms/step
#  70%|███████   | 14/20 [00:12<00:04,  1.26it/s]
# 1/1 [==============================] - 0s 390ms/step
#  75%|███████▌  | 15/20 [00:13<00:04,  1.25it/s]
# 1/1 [==============================] - 0s 386ms/step
#  80%|████████  | 16/20 [00:14<00:03,  1.26it/s]
# 1/1 [==============================] - 0s 447ms/step
#  85%|████████▌ | 17/20 [00:15<00:02,  1.22it/s]
# 1/1 [==============================] - 0s 384ms/step
#  90%|█████████ | 18/20 [00:16<00:01,  1.26it/s]
# 1/1 [==============================] - 0s 413ms/step
#  95%|█████████▌| 19/20 [00:17<00:00,  1.25it/s]
# 1/1 [==============================] - 0s 484ms/step
# 100%|██████████| 20/20 [00:17<00:00,  1.12it/s]

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
# concatenate to single array
out_cat_y = np.argmax(np.concatenate(out_y, 0), -1)
pred_cat_y = np.argmax(np.concatenate(pred_y, 0), -1)
pred_conf_y = np.concatenate(pred_y, 0)[:,1]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(out_cat_y, pred_cat_y))
plt.matshow(confusion_matrix(out_cat_y, pred_cat_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.88      0.73       185
#            1       0.90      0.66      0.76       295
#
#     accuracy                           0.74       480
#    macro avg       0.76      0.77      0.74       480
# weighted avg       0.79      0.74      0.75       480

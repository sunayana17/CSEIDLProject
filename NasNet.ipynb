# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from os.path import join
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
class_enc = LabelEncoder()
import pickle
import tensorflow as tf
import cv2
import keras.backend as K
# Out:
# /packages/7x/anaconda3/5.3.0/envs/tf2.4.1-gpu/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# 2022-12-02 14:01:09.106198: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-02 14:01:09.260463: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-02 14:01:09.300948: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-02 14:01:12.850042: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /packages/7x/anaconda3/5.3.0/lib
# 2022-12-02 14:01:12.851707: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /packages/7x/anaconda3/5.3.0/lib
# 2022-12-02 14:01:12.851748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# %pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already up-to-date: scikit-learn in /home/sgupt279/.local/lib/python3.8/site-packages (1.1.3)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/sgupt279/.local/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3 in /home/sgupt279/.local/lib/python3.8/site-packages (from scikit-learn) (1.23.3)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.2 in /packages/7x/anaconda3/5.3.0/envs/tf2.4.1-gpu/lib/python3.8/site-packages (from scikit-learn) (1.6.2)
# Requirement already satisfied, skipping upgrade: joblib>=1.0.0 in /home/sgupt279/.local/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# params we will probably want to do some hyperparameter optimization later
BASE_MODEL= 'NASNetLarge' # ['VGG16', 'RESNET52', 'InceptionV3', 'Xception', 'DenseNet169', 'DenseNet121']
IMG_SIZE = (384, 384) # [(224, 224), (384, 384), (512, 512), (640, 640)]
BATCH_SIZE = 24 # [1, 8, 16, 24]
DENSE_COUNT = 128 # [32, 64, 128, 256]
DROPOUT = 0.25 # [0, 0.25, 0.5]
LEARN_RATE = 1e-4 # [1e-4, 1e-3, 4e-3]
TRAIN_SAMPLES = 8000 # [3000, 6000, 15000]
TEST_SAMPLES = 800
USE_ATTN = False # [True, False]

# %%
from keras.preprocessing.image import ImageDataGenerator
if BASE_MODEL=='VGG16':
    from keras.applications.vgg16 import VGG16 as PTModel, preprocess_input
elif BASE_MODEL=='RESNET52':
    from keras.applications.resnet import ResNet50 as PTModel, preprocess_input
elif BASE_MODEL=='InceptionV3':
    from keras.applications.inception_v3 import InceptionV3 as PTModel, preprocess_input
elif BASE_MODEL=='DenseNet169': 
    from keras.applications.densenet import DenseNet169 as PTModel, preprocess_input
elif BASE_MODEL=='NASNetLarge':
    from keras.applications.nasnet import NASNetLarge as PTModel, preprocess_input
else:
    raise ValueError('Unknown model: {}'.format(BASE_MODEL))

# %%
img_gen_args = dict(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range = 0.05, 
                              width_shift_range = 0.02, 
                              rotation_range = 3, 
                              shear_range = 0.01,
                              fill_mode = 'nearest',
                              zoom_range = 0.05,
                               preprocessing_function=preprocess_input)
img_gen = ImageDataGenerator(**img_gen_args)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_HUMERUS.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_HUMERUS.csv", dtype=str)
train_df
# Out:
#                                             Train_Image Train_Label
# 0     MURA-v1.1/train/XR_HUMERUS/patient02695/study1...           1
# 1     MURA-v1.1/train/XR_HUMERUS/patient02626/study1...           1
# 2     MURA-v1.1/train/XR_HUMERUS/patient02626/study1...           1
# 3     MURA-v1.1/train/XR_HUMERUS/patient02696/study1...           1
# 4     MURA-v1.1/train/XR_HUMERUS/patient02696/study1...           1
# ...                                                 ...         ...
# 1267  MURA-v1.1/train/XR_HUMERUS/patient03224/study1...           0
# 1268  MURA-v1.1/train/XR_HUMERUS/patient03225/study1...           0
# 1269  MURA-v1.1/train/XR_HUMERUS/patient03225/study1...           0
# 1270  MURA-v1.1/train/XR_HUMERUS/patient03226/study1...           0
# 1271  MURA-v1.1/train/XR_HUMERUS/patient03226/study1...           0
#
# [1272 rows x 2 columns]

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_ELBOW.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_ELBOW.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_SHOULDER.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_SHOULDER.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_HAND.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_HAND.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_FINGER.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_FINGER.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_FOREARM.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_FOREARM.csv", dtype=str)

# %%
# Read Training and Validation .csv files
train_df = pd.read_csv("./Train_set_WRIST.csv", dtype=str)
valid_df = pd.read_csv("./Valid_set_WRIST.csv", dtype=str)

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Image Preprocessing
train_generator = train_datagen.flow_from_dataframe(dataframe=train_df, directory=None,
                                              x_col="Train_Image", y_col="Train_Label",
                                              target_size=(224,224), class_mode="categorical",
                                              batch_size=BATCH_SIZE, shuffle=True)

validation_generator = validation_datagen.flow_from_dataframe(dataframe=valid_df, directory=None,
                                              x_col="Valid_Image", y_col="Valid_Label",
                                              target_size=(224,224), class_mode="categorical",
                                              batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Found 9752 validated image filenames belonging to 2 classes.
# Found 659 validated image filenames belonging to 2 classes.

# %%
t_x, t_y = next(train_generator)
print(t_x.shape, t_y.shape)
fig, m_axs = plt.subplots(2, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    #c_ax.set_title('%s' % class_enc.classes_[np.argmax(c_y)])
    c_ax.axis('off')
# Out:
# (24, 224, 224, 3) (24, 2)

# %%
base_pretrained_model = PTModel(input_shape =  t_x.shape[1:], 
                              include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False
# Out:
# 2022-12-02 14:02:00.853032: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sgupt279/.local/lib/python3.8/site-packages/cv2/../../lib64:/packages/7x/anaconda3/5.3.0/lib
# 2022-12-02 14:02:00.853087: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-02 14:02:00.853990: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
t_x.shape[1:]
# Out:
# (224, 224, 3)

# %%
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, Input, Conv2D, multiply, LocallyConnected2D, Lambda, AvgPool2D
from keras.models import Model
from keras.optimizers import Adam
from keras import layers
in_lay = Input(t_x.shape[1:])
pt_features = base_pretrained_model(in_lay)
#pt_features = Input(base_pretrained_model.get_output_shape_at(0)[1:], name = 'feature_input')
pt_depth = base_pretrained_model.get_output_shape_at(0)[-1]
from keras.layers import BatchNormalization
bn_features = BatchNormalization()(pt_features)
gap = GlobalAveragePooling2D()(bn_features)

gap_dr = Dropout(DROPOUT)(gap)
dr_steps = Dropout(DROPOUT)(Dense(DENSE_COUNT, activation = 'linear', use_bias=False)(gap_dr))
dr_steps = BatchNormalization()(dr_steps)
dr_steps = layers.LeakyReLU(0.1)(dr_steps)
out_layer = Dense(t_y.shape[1], activation = 'softmax')(dr_steps)

attn_model = Model(inputs = [pt_features], 
                   outputs = [out_layer], name = 'trained_model')

attn_model.summary()
# Out:
# Model: "trained_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 7, 7, 4032)]      0
#
#  batch_normalization (BatchN  (None, 7, 7, 4032)       16128
#  ormalization)
#
#  global_average_pooling2d (G  (None, 4032)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 4032)              0
#
#  dense (Dense)               (None, 128)               516096
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 532,994
# Trainable params: 524,674
# Non-trainable params: 8,320
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.optimizers import Adam
pneu_model = Sequential(name = 'combined_model')
base_pretrained_model.trainable = False
pneu_model.add(base_pretrained_model)
pneu_model.add(attn_model)
pneu_model.compile(optimizer = Adam(lr = LEARN_RATE), loss = 'categorical_crossentropy',
                           metrics = ['categorical_accuracy'])
pneu_model.summary()
# Out:
# Model: "combined_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  NASNet (Functional)         (None, 7, 7, 4032)        84916818
#
#  trained_model (Functional)  (None, 2)                 532994
#
# =================================================================
# Total params: 85,449,812
# Trainable params: 524,674
# Non-trainable params: 84,925,138
# _________________________________________________________________
# /home/sgupt279/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('lung_opacity1')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, 
                                   patience=10, verbose=1, mode='auto', 
                                   epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=10) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
train_generator.batch_size = BATCH_SIZE
history=pneu_model.fit_generator(train_generator, 
                         steps_per_epoch=train_generator.n//BATCH_SIZE,
                         validation_data=validation_generator, 
                         validation_steps=validation_generator.n//BATCH_SIZE,
                         epochs=30, 
                         callbacks=callbacks_list,
                         workers=2)
# Out:
# /tmp/ipykernel_169038/3775246973.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=pneu_model.fit_generator(train_generator,
# Epoch 1/30
# 406/406 [==============================] - ETA: 0s - loss: 0.6808 - categorical_accuracy: 0.6651
# Epoch 1: val_loss improved from inf to 0.56367, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 740s 2s/step - loss: 0.6808 - categorical_accuracy: 0.6651 - val_loss: 0.5637 - val_categorical_accuracy: 0.7052 - lr: 1.0000e-04
# Epoch 2/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5849 - categorical_accuracy: 0.7081
# Epoch 2: val_loss improved from 0.56367 to 0.54671, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 692s 2s/step - loss: 0.5849 - categorical_accuracy: 0.7081 - val_loss: 0.5467 - val_categorical_accuracy: 0.7330 - lr: 1.0000e-04
# Epoch 3/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5713 - categorical_accuracy: 0.7170
# Epoch 3: val_loss improved from 0.54671 to 0.54608, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 677s 2s/step - loss: 0.5713 - categorical_accuracy: 0.7170 - val_loss: 0.5461 - val_categorical_accuracy: 0.7253 - lr: 1.0000e-04
# Epoch 4/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5492 - categorical_accuracy: 0.7347
# Epoch 4: val_loss improved from 0.54608 to 0.53107, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 680s 2s/step - loss: 0.5492 - categorical_accuracy: 0.7347 - val_loss: 0.5311 - val_categorical_accuracy: 0.7330 - lr: 1.0000e-04
# Epoch 5/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5402 - categorical_accuracy: 0.7336
# Epoch 5: val_loss improved from 0.53107 to 0.52322, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 703s 2s/step - loss: 0.5402 - categorical_accuracy: 0.7336 - val_loss: 0.5232 - val_categorical_accuracy: 0.7361 - lr: 1.0000e-04
# Epoch 6/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5380 - categorical_accuracy: 0.7293
# Epoch 6: val_loss improved from 0.52322 to 0.50827, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 679s 2s/step - loss: 0.5380 - categorical_accuracy: 0.7293 - val_loss: 0.5083 - val_categorical_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 7/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5290 - categorical_accuracy: 0.7404
# Epoch 7: val_loss improved from 0.50827 to 0.50688, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 689s 2s/step - loss: 0.5290 - categorical_accuracy: 0.7404 - val_loss: 0.5069 - val_categorical_accuracy: 0.7485 - lr: 1.0000e-04
# Epoch 8/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5295 - categorical_accuracy: 0.7417
# Epoch 8: val_loss did not improve from 0.50688
# 406/406 [==============================] - 698s 2s/step - loss: 0.5295 - categorical_accuracy: 0.7417 - val_loss: 0.5089 - val_categorical_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 9/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5208 - categorical_accuracy: 0.7444
# Epoch 9: val_loss did not improve from 0.50688
# 406/406 [==============================] - 665s 2s/step - loss: 0.5208 - categorical_accuracy: 0.7444 - val_loss: 0.5104 - val_categorical_accuracy: 0.7531 - lr: 1.0000e-04
# Epoch 10/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5256 - categorical_accuracy: 0.7428
# Epoch 10: val_loss did not improve from 0.50688
# 406/406 [==============================] - 586s 1s/step - loss: 0.5256 - categorical_accuracy: 0.7428 - val_loss: 0.5181 - val_categorical_accuracy: 0.7485 - lr: 1.0000e-04
# Epoch 11/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5182 - categorical_accuracy: 0.7429
# Epoch 11: val_loss did not improve from 0.50688
# 406/406 [==============================] - 590s 1s/step - loss: 0.5182 - categorical_accuracy: 0.7429 - val_loss: 0.5178 - val_categorical_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 12/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5124 - categorical_accuracy: 0.7496
# Epoch 12: val_loss improved from 0.50688 to 0.50078, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 574s 1s/step - loss: 0.5124 - categorical_accuracy: 0.7496 - val_loss: 0.5008 - val_categorical_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 13/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5075 - categorical_accuracy: 0.7537
# Epoch 13: val_loss improved from 0.50078 to 0.49719, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 513s 1s/step - loss: 0.5075 - categorical_accuracy: 0.7537 - val_loss: 0.4972 - val_categorical_accuracy: 0.7654 - lr: 1.0000e-04
# Epoch 14/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5031 - categorical_accuracy: 0.7558
# Epoch 14: val_loss did not improve from 0.49719
# 406/406 [==============================] - 449s 1s/step - loss: 0.5031 - categorical_accuracy: 0.7558 - val_loss: 0.5045 - val_categorical_accuracy: 0.7454 - lr: 1.0000e-04
# Epoch 15/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5004 - categorical_accuracy: 0.7557
# Epoch 15: val_loss did not improve from 0.49719
# 406/406 [==============================] - 467s 1s/step - loss: 0.5004 - categorical_accuracy: 0.7557 - val_loss: 0.5094 - val_categorical_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 16/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5037 - categorical_accuracy: 0.7547
# Epoch 16: val_loss did not improve from 0.49719
# 406/406 [==============================] - 464s 1s/step - loss: 0.5037 - categorical_accuracy: 0.7547 - val_loss: 0.4998 - val_categorical_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 17/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5066 - categorical_accuracy: 0.7490
# Epoch 17: val_loss improved from 0.49719 to 0.48942, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 415s 1s/step - loss: 0.5066 - categorical_accuracy: 0.7490 - val_loss: 0.4894 - val_categorical_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 18/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5007 - categorical_accuracy: 0.7578
# Epoch 18: val_loss did not improve from 0.48942
# 406/406 [==============================] - 353s 869ms/step - loss: 0.5007 - categorical_accuracy: 0.7578 - val_loss: 0.4954 - val_categorical_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 19/30
# 406/406 [==============================] - ETA: 0s - loss: 0.5037 - categorical_accuracy: 0.7531
# Epoch 19: val_loss did not improve from 0.48942
# 406/406 [==============================] - 228s 560ms/step - loss: 0.5037 - categorical_accuracy: 0.7531 - val_loss: 0.4928 - val_categorical_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 20/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4972 - categorical_accuracy: 0.7573
# Epoch 20: val_loss did not improve from 0.48942
# 406/406 [==============================] - 232s 571ms/step - loss: 0.4972 - categorical_accuracy: 0.7573 - val_loss: 0.4901 - val_categorical_accuracy: 0.7577 - lr: 1.0000e-04
# Epoch 21/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4953 - categorical_accuracy: 0.7612
# Epoch 21: val_loss did not improve from 0.48942
# 406/406 [==============================] - 233s 573ms/step - loss: 0.4953 - categorical_accuracy: 0.7612 - val_loss: 0.4898 - val_categorical_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 22/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4918 - categorical_accuracy: 0.7609
# Epoch 22: val_loss improved from 0.48942 to 0.48211, saving model to lung_opacity1_weights.best.hdf5
# 406/406 [==============================] - 232s 570ms/step - loss: 0.4918 - categorical_accuracy: 0.7609 - val_loss: 0.4821 - val_categorical_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 23/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4955 - categorical_accuracy: 0.7579
# Epoch 23: val_loss did not improve from 0.48211
# 406/406 [==============================] - 233s 572ms/step - loss: 0.4955 - categorical_accuracy: 0.7579 - val_loss: 0.4859 - val_categorical_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 24/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4915 - categorical_accuracy: 0.7680
# Epoch 24: val_loss did not improve from 0.48211
# 406/406 [==============================] - 231s 568ms/step - loss: 0.4915 - categorical_accuracy: 0.7680 - val_loss: 0.4863 - val_categorical_accuracy: 0.7685 - lr: 1.0000e-04
# Epoch 25/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4878 - categorical_accuracy: 0.7662
# Epoch 25: val_loss did not improve from 0.48211
# 406/406 [==============================] - 231s 567ms/step - loss: 0.4878 - categorical_accuracy: 0.7662 - val_loss: 0.4958 - val_categorical_accuracy: 0.7531 - lr: 1.0000e-04
# Epoch 26/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4925 - categorical_accuracy: 0.7622
# Epoch 26: val_loss did not improve from 0.48211
# 406/406 [==============================] - 232s 569ms/step - loss: 0.4925 - categorical_accuracy: 0.7622 - val_loss: 0.4935 - val_categorical_accuracy: 0.7438 - lr: 1.0000e-04
# Epoch 27/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4844 - categorical_accuracy: 0.7633
# Epoch 27: val_loss did not improve from 0.48211
# 406/406 [==============================] - 233s 572ms/step - loss: 0.4844 - categorical_accuracy: 0.7633 - val_loss: 0.4823 - val_categorical_accuracy: 0.7515 - lr: 1.0000e-04
# Epoch 28/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4953 - categorical_accuracy: 0.7605
# Epoch 28: val_loss did not improve from 0.48211
# 406/406 [==============================] - 232s 571ms/step - loss: 0.4953 - categorical_accuracy: 0.7605 - val_loss: 0.4884 - val_categorical_accuracy: 0.7654 - lr: 1.0000e-04
# Epoch 29/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4927 - categorical_accuracy: 0.7656
# Epoch 29: val_loss did not improve from 0.48211
# 406/406 [==============================] - 230s 564ms/step - loss: 0.4927 - categorical_accuracy: 0.7656 - val_loss: 0.4992 - val_categorical_accuracy: 0.7454 - lr: 1.0000e-04
# Epoch 30/30
# 406/406 [==============================] - ETA: 0s - loss: 0.4934 - categorical_accuracy: 0.7606
# Epoch 30: val_loss did not improve from 0.48211
# 406/406 [==============================] - 229s 562ms/step - loss: 0.4934 - categorical_accuracy: 0.7606 - val_loss: 0.4996 - val_categorical_accuracy: 0.7469 - lr: 1.0000e-04

# %%
with open('elbow_vgg16_model.pkl', 'wb') as pickle_out:  
    pickle.dump(history, pickle_out)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) NASNet_input with unsupported characters which will be renamed to nasnet_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 268). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://379f28ba-9afc-4ca5-b459-e9612aba35e8/assets
# INFO:tensorflow:Assets written to: ram://379f28ba-9afc-4ca5-b459-e9612aba35e8/assets

# %%
# %pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /home/sgupt279/.local/lib/python3.8/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm


valid_flow = validation_datagen.flow_from_dataframe(dataframe=valid_df, directory=None,
                                              x_col="Valid_Image", y_col="Valid_Label",
                                              target_size=(224,224), class_mode="categorical",
                                              batch_size=BATCH_SIZE, shuffle=False)


out_x, out_y, pred_y = [], [], []
for _, (tX, tY) in zip(tqdm(range(len(valid_flow.filenames)//32)), valid_flow):
    out_x += [tX]
    out_y += [tY]
    pred_y += [pneu_model.predict(tX)]
# Out:
# Found 659 validated image filenames belonging to 2 classes.
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 [==============================] - 6s 6s/step
#   5%|▌         | 1/20 [00:05<01:53,  5.96s/it]
# 1/1 [==============================] - 1s 530ms/step
#  10%|█         | 2/20 [00:06<00:51,  2.85s/it]
# 1/1 [==============================] - 1s 535ms/step
#  15%|█▌        | 3/20 [00:07<00:31,  1.87s/it]
# 1/1 [==============================] - 1s 535ms/step
#  20%|██        | 4/20 [00:08<00:22,  1.41s/it]
# 1/1 [==============================] - 1s 547ms/step
#  25%|██▌       | 5/20 [00:08<00:17,  1.16s/it]
# 1/1 [==============================] - 1s 535ms/step
#  30%|███       | 6/20 [00:09<00:14,  1.01s/it]
# 1/1 [==============================] - 1s 533ms/step
#  35%|███▌      | 7/20 [00:10<00:11,  1.11it/s]
# 1/1 [==============================] - 1s 538ms/step
#  40%|████      | 8/20 [00:10<00:09,  1.20it/s]
# 1/1 [==============================] - 1s 613ms/step
#  45%|████▌     | 9/20 [00:11<00:08,  1.23it/s]
# 1/1 [==============================] - 1s 592ms/step
#  50%|█████     | 10/20 [00:12<00:07,  1.26it/s]
# 1/1 [==============================] - 1s 598ms/step
#  55%|█████▌    | 11/20 [00:13<00:07,  1.28it/s]
# 1/1 [==============================] - 1s 575ms/step
#  60%|██████    | 12/20 [00:13<00:06,  1.31it/s]
# 1/1 [==============================] - 1s 595ms/step
#  65%|██████▌   | 13/20 [00:14<00:05,  1.31it/s]
# 1/1 [==============================] - 1s 587ms/step
#  70%|███████   | 14/20 [00:15<00:04,  1.32it/s]
# 1/1 [==============================] - 1s 590ms/step
#  75%|███████▌  | 15/20 [00:16<00:03,  1.31it/s]
# 1/1 [==============================] - 1s 578ms/step
#  80%|████████  | 16/20 [00:16<00:03,  1.31it/s]
# 1/1 [==============================] - 1s 571ms/step
#  85%|████████▌ | 17/20 [00:17<00:02,  1.32it/s]
# 1/1 [==============================] - 1s 570ms/step
#  90%|█████████ | 18/20 [00:18<00:01,  1.32it/s]
# 1/1 [==============================] - 1s 600ms/step
#  95%|█████████▌| 19/20 [00:19<00:00,  1.32it/s]
# 1/1 [==============================] - 1s 610ms/step
# 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
pneu_model.load_weights(weight_path)
pneu_model.save('full_model.h5')

# %%
# concatenate to single array
out_cat_y = np.argmax(np.concatenate(out_y, 0), -1)
pred_cat_y = np.argmax(np.concatenate(pred_y, 0), -1)
pred_conf_y = np.concatenate(pred_y, 0)[:,1]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(out_cat_y, pred_cat_y))
plt.matshow(confusion_matrix(out_cat_y, pred_cat_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.91      0.70       185
#            1       0.91      0.57      0.70       295
#
#     accuracy                           0.70       480
#    macro avg       0.74      0.74      0.70       480
# weighted avg       0.78      0.70      0.70       480
